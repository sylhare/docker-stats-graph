# %% [markdown]
# # Docker Stats Example
#
# ## With Docker stats values
#
# Run the `scrips/generate_data.sh`, this will produce a data.csv that will be used to create the graphs.
#
# Import the local library then pass the file as parameter.

# %%
from src.dockerstats import *

# %%
ds = DockerStats("tests/resources/data.csv")
print(ds.df)
# Out:
#                   NAME  CPU %  MEM %    MEM Usage  PID                DATE  \
# 0   determined_mestorf    1.0   0.13     7.465000    1 2020-11-16 22:36:29
# 1        cautious_bach    9.0   0.50   465.000000    1 2020-11-16 22:36:29
# 2   determined_mestorf   10.0   0.13  7465.000000    1 2020-11-16 22:36:36
# 3        cautious_bach    9.0   0.27     0.007465    1 2020-11-16 22:36:36
# 4   determined_mestorf    8.0   0.34     7.465000    1 2020-11-16 22:36:42
# 5        cautious_bach    6.0   0.64     7.465000    1 2020-11-16 22:36:42
# 6   determined_mestorf    4.0   0.19     7.465000    1 2020-11-16 22:36:49
# 7        cautious_bach    5.0   0.79     7.465000    1 2020-11-16 22:36:49
# 8   determined_mestorf    9.0   0.83     7.465000    1 2020-11-16 22:36:56
# 9        cautious_bach    2.0   0.82     7.465000    1 2020-11-16 22:36:56
# 10  determined_mestorf    3.0   0.52  2965.000000    1 2020-11-16 22:37:03
# 11       cautious_bach    4.0   0.64  4465.000000    1 2020-11-16 22:37:03
# 12  determined_mestorf    1.0   0.43  2465.000000    1 2020-11-16 22:37:09
# 13       cautious_bach    6.0   0.56     2.465000    1 2020-11-16 22:37:09
# 14  determined_mestorf    7.0   0.85     5.465000    1 2020-11-16 22:37:16
# 15       cautious_bach    9.0   0.22     7.465000    1 2020-11-16 22:37:16
# 16  determined_mestorf    2.0   0.13     7.465000    1 2020-11-16 22:37:23
# 17       cautious_bach    3.0   0.56     7.465000    1 2020-11-16 22:37:23
# 18  determined_mestorf    1.0   0.42  7565.000000    1 2020-11-16 22:37:30
# 19       cautious_bach    5.0   0.63     8.465000    1 2020-11-16 22:37:30
#
#     NET INPUT  NET OUTPUT  BLOCK INPUT  BLOCK OUTPUT
# 0       106.0        2.17        0.262          2.14
# 1       156.0        2.17        0.262          5.14
# 2       506.0        2.17        2.362          2.14
# 3       196.0        2.17        0.262          6.14
# 4       606.0        6.17        0.562          2.14
# 5       146.0        2.17        0.262          7.14
# 6       906.0        3.17        0.462          2.14
# 7       306.0        2.17        0.262          4.14
# 8       206.0        8.17        0.962          2.14
# 9       406.0        4.17        0.262          1.14
# 10      806.0        5.17        0.962          2.14
# 11      306.0        5.17        0.262          2.14
# 12      206.0        8.17        0.862          2.14
# 13      156.0        9.17        0.262          3.14
# 14      406.0        2.17        0.462          8.14
# 15      606.0        1.17        0.262          2.14
# 16      706.0        5.17        0.662          7.14
# 17      806.0        6.17        0.262          4.14
# 18      306.0        4.17        2.462          4.14
# 19      206.0        3.17        0.762          3.14

# %%
ds.plot_category('MEM Usage')

# %%
ds.plot_category_all()

# %% [markdown]
# ## With Jmeter values
#
# If you run jmeter, you can use the `.jtl` or any `.csv` report you would like.
#
# Note:
#  - You can use default `jmeter -g output.csv -o report` to generate a report.

# %%
from src.jmeter import *

# %%
jm = Jmeter("tests/resources/output.jtl")
if verbose:print(jm.df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ffc60d655df2> in <module>
#       1 jm = Jmeter("tests/resources/output.jtl")
# ----> 2 if verbose:print(jm.df)
#
# NameError: name 'verbose' is not defined

# %%
print("The duration time is of \t\t\t" + str(jm.duration_min()) + " min")
print("The average transaction per second is of \t" + str(jm.tps_avg()) + " tps")
print("The average latency is of  \t\t\t" + str(jm.latency_avg()) + " ms")
print("The average response time is of \t\t" + str(jm.response_time_avg()) + " ms")
# Out:
# The duration time is of 			0.15 min
# The average transaction per second is of 	12.0 tps
# The average latency is of  			38.569 ms
# The average response time is of 		77.211 ms
